# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/audible-uncleaned-date-changed/audible_uncleaned(in).csv

# %% [markdown]
# ### Load unclean data

# %%
df = pd.read_csv('/kaggle/input/audible-uncleaned-date-changed/audible_uncleaned(in).csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 87489 entries, 0 to 87488
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   name         87489 non-null  object
#  1   author       87489 non-null  object
#  2   narrator     87489 non-null  object
#  3   time         87489 non-null  object
#  4   releasedate  87489 non-null  object
#  5   language     87489 non-null  object
#  6   stars        87489 non-null  object
#  7   price        87489 non-null  object
# dtypes: object(8)
# memory usage: 5.3+ MB

# %%
df.head(10)
# Out:
#                                          name                     author  \
# 0                  Geronimo Stilton #11 & #12  Writtenby:GeronimoStilton
# 1                            The Burning Maze      Writtenby:RickRiordan
# 2                                The Deep End       Writtenby:JeffKinney
# 3                        Daughter of the Deep      Writtenby:RickRiordan
# 4  The Lightning Thief: Percy Jackson, Book 1      Writtenby:RickRiordan
# 5           The Hunger Games: Special Edition   Writtenby:SuzanneCollins
# 6                 Quest for the Diamond Sword     Writtenby:WinterMorgan
# 7                           The Dark Prophecy      Writtenby:RickRiordan
# 8                   Merlin Mission Collection  Writtenby:MaryPopeOsborne
# 9                           The Tyrant’s Tomb      Writtenby:RickRiordan
#
#                      narrator                time releasedate language  \
# 0       Narratedby:BillLobely   2 hrs and 20 mins   8/04/2008  English
# 1    Narratedby:RobbieDaymond   13 hrs and 8 mins   5/01/2018  English
# 2       Narratedby:DanRussell    2 hrs and 3 mins  11/06/2020  English
# 3   Narratedby:SoneelaNankani  11 hrs and 16 mins  10/05/2021  English
# 4   Narratedby:JesseBernstein              10 hrs  13/01/2010  English
# 5   Narratedby:TatianaMaslany  10 hrs and 35 mins    30-10-18  English
# 6      Narratedby:LukeDaniels   2 hrs and 23 mins    25-11-14  English
# 7    Narratedby:RobbieDaymond  12 hrs and 32 mins   5/02/2017  English
# 8  Narratedby:MaryPopeOsborne  10 hrs and 56 mins   5/02/2017  English
# 9    Narratedby:RobbieDaymond  13 hrs and 22 mins    24-09-19  English
#
#                            stars     price
# 0     5 out of 5 stars34 ratings       468
# 1   4.5 out of 5 stars41 ratings       820
# 2   4.5 out of 5 stars38 ratings       410
# 3   4.5 out of 5 stars12 ratings       615
# 4  4.5 out of 5 stars181 ratings       820
# 5     5 out of 5 stars72 ratings       656
# 6     5 out of 5 stars11 ratings       233
# 7     5 out of 5 stars50 ratings       820
# 8      5 out of 5 stars5 ratings  1,256.00
# 9     5 out of 5 stars58 ratings       820

# %%
df.tail(10)
# Out:
#                             name                              author  \
# 87479           Dear Bob and Sue      Writtenby:MattSmith,KarenSmith
# 87480        Journey into Cyprus              Writtenby:ColinThubron
# 87481        The Hills of Adonis              Writtenby:ColinThubron
# 87482                   The Bush  Writtenby:DonWatson,HamishHamilton
# 87483        We Stood upon Stars           Writtenby:RogerW.Thompson
# 87484  Last Days of the Bus Club              Writtenby:ChrisStewart
# 87485                   The Alps             Writtenby:StephenO'Shea
# 87486       The Innocents Abroad                 Writtenby:MarkTwain
# 87487      A Sentimental Journey            Writtenby:LaurenceSterne
# 87488                     Havana             Writtenby:MarkKurlansky
#
#                                     narrator                time releasedate  \
# 87479  Narratedby:DavidColacci,SusanEricksen  14 hrs and 48 mins    26-12-17
# 87480              Narratedby:JonathanKeeble  11 hrs and 51 mins   1/01/2018
# 87481              Narratedby:JonathanKeeble   6 hrs and 52 mins  12/01/2017
# 87482                   Narratedby:DonWatson  13 hrs and 16 mins    13-10-17
# 87483                  Narratedby:JohnMcLain   5 hrs and 55 mins   5/02/2017
# 87484                Narratedby:ChrisStewart   7 hrs and 34 mins   3/09/2017
# 87485                  Narratedby:RobertFass   10 hrs and 7 mins    21-02-17
# 87486                   Narratedby:FloGibson   19 hrs and 4 mins    30-12-16
# 87487                 Narratedby:AntonLesser    4 hrs and 8 mins    23-02-11
# 87488                 Narratedby:FleetCooper     6 hrs and 1 min   3/07/2017
#
#       language          stars     price
# 87479  English  Not rated yet  1,055.00
# 87480  English  Not rated yet       785
# 87481  English  Not rated yet       679
# 87482  English  Not rated yet  1,328.00
# 87483  English  Not rated yet       351
# 87484  English  Not rated yet       596
# 87485  English  Not rated yet       820
# 87486  English  Not rated yet       938
# 87487  English  Not rated yet       680
# 87488  English  Not rated yet       569

# %%
df[df.name.duplicated()]
# Out:
#                                              name  \
# 18                      Merlin Mission Collection
# 46     The Lightning Thief: Percy Jackson, Book 1
# 54                      Merlin Mission Collection
# 155                        Barbie - Superprincesa
# 273                           Barbie - Dreamtopia
# ...                                           ...
# 87443       Travels with a Donkey in the Cevennes
# 87456                                  Gettysburg
# 87457                                        Solo
# 87475                                  Wanderlust
# 87486                        The Innocents Abroad
#
#                                           author  \
# 18                     Writtenby:MaryPopeOsborne
# 46                         Writtenby:RickRiordan
# 54                     Writtenby:MaryPopeOsborne
# 155                             Writtenby:Mattel
# 273    Writtenby:Mattel,MartaCisaMuñoz-traductor
# ...                                          ...
# 87443             Writtenby:RobertLouisStevenson
# 87456                       Writtenby:JeffShaara
# 87457                         Writtenby:PenHadow
# 87475                   Writtenby:ElisabethEaves
# 87486                        Writtenby:MarkTwain
#
#                             narrator                time releasedate language  \
# 18        Narratedby:MaryPopeOsborne  10 hrs and 18 mins   5/02/2017  English
# 46            Narratedby:WalterLewis   3 hrs and 51 mins    13-01-10  English
# 54        Narratedby:MaryPopeOsborne  13 hrs and 24 mins   5/02/2017  English
# 155    Narratedby:VanessaPérezJurado             29 mins   3/07/2022  spanish
# 273         Narratedby:MiriamMonlleo             21 mins    31-01-22  catalan
# ...                              ...                 ...         ...      ...
# 87443         Narratedby:DenisLawson   2 hrs and 51 mins    13-05-08  English
# 87456       Narratedby:RobertsonDean    1 hr and 12 mins    26-03-07  English
# 87457            Narratedby:PenHadow    3 hrs and 5 mins    14-02-05  English
# 87475         Narratedby:ErinBennett   9 hrs and 51 mins    26-02-14  English
# 87486           Narratedby:FloGibson   19 hrs and 4 mins    30-12-16  English
#
#                             stars     price
# 18     5 out of 5 stars11 ratings  1,256.00
# 46      4 out of 5 stars4 ratings       615
# 54      5 out of 5 stars8 ratings  1,256.00
# 155                 Not rated yet        38
# 273                 Not rated yet        38
# ...                           ...       ...
# 87443               Not rated yet       569
# 87456               Not rated yet       200
# 87457               Not rated yet       615
# 87475               Not rated yet       668
# 87486               Not rated yet       938
#
# [4722 rows x 8 columns]

# %%
df[df.name=='Travels with a Donkey in the Cevennes']
# Out:
#                                         name                          author  \
# 19319  Travels with a Donkey in the Cevennes  Writtenby:RobertLouisStevenson
# 85956  Travels with a Donkey in the Cevennes  Writtenby:RobertLouisStevenson
# 87443  Travels with a Donkey in the Cevennes  Writtenby:RobertLouisStevenson
#
#                          narrator               time releasedate language  \
# 19319     Narratedby:BillyHartman  2 hrs and 38 mins    26-12-99  English
# 85956  Narratedby:MelissaThompson  3 hrs and 27 mins   3/10/2020  English
# 87443      Narratedby:DenisLawson  2 hrs and 51 mins    13-05-08  English
#
#                stars     price
# 19319  Not rated yet       375
# 85956  Not rated yet  1,055.00
# 87443  Not rated yet       569

# %% [markdown]
# Though the names are same, the narrators are different so we need to consider that all the data are unique and not duplicated.

# %% [markdown]
# ### Messy Data
# 1. author column
#    * Writtneby:
#    * First Name, Middle Name, Last Name combined
#    * Multiple authors combined
# 2. narrator column
#    * Narratedby:
#    * First Name, Middle Name, Last Name combined
# 3. time column
#    * time in string format
# 4. releasedate
#    * different date format
#    * some with - and some with /
# 5. language column
#    * incositent case
# 6. stars column
#    * stars and rating counts in same column
# 7. price column
#    * price in string format
#    * contains , in between

# %% [markdown]
# #### Import necessary libraries

# %%
import re
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import FunctionTransformer

# %%
def clean_name(name_series):
    # Ensure the input is a pandas Series
    if not isinstance(name_series, pd.Series):
        raise TypeError("Expected a pandas Series")

    # Apply cleaning operations
    cleaned_names = name_series.str.replace(r'Writtenby:', '', regex=True)  # Remove 'Writtenby:'
    cleaned_names = cleaned_names.str.replace(r'Narratedby:', '', regex=True)  # Remove 'Writtenby:'
    spaced_names = cleaned_names.str.replace(r'([a-z])([A-Z])', r'\1 \2', regex=True)  # Add spaces

    return spaced_names.to_frame()

clean_name_transformer = FunctionTransformer(clean_name)

# %%
clean_name_transformer.transform(df['author'])
# Out:
#                  author
# 0      Geronimo Stilton
# 1          Rick Riordan
# 2           Jeff Kinney
# 3          Rick Riordan
# 4          Rick Riordan
# ...                 ...
# 87484     Chris Stewart
# 87485    Stephen O'Shea
# 87486        Mark Twain
# 87487   Laurence Sterne
# 87488    Mark Kurlansky
#
# [87489 rows x 1 columns]

# %%
clean_name_transformer.transform(df['narrator'])
# Out:
#               narrator
# 0          Bill Lobely
# 1       Robbie Daymond
# 2          Dan Russell
# 3      Soneela Nankani
# 4      Jesse Bernstein
# ...                ...
# 87484    Chris Stewart
# 87485      Robert Fass
# 87486       Flo Gibson
# 87487     Anton Lesser
# 87488     Fleet Cooper
#
# [87489 rows x 1 columns]

# %%
# Parse hours and minutes for each entry in the Series
def parse_time_string(time):
    hours_match = re.search(r'(\d+)\s*hrs?', time)
    mins_match = re.search(r'(\d+)\s*mins?', time)
    
    # Extract hours and minutes, default to 0 if not found
    hours = int(hours_match.group(1)) if hours_match else 0
    minutes = int(mins_match.group(1)) if mins_match else 0
    
    # Calculate total minutes
    return hours * 60 + minutes

def convert_to_minutes_series(time_series):
    # Ensure the input is a pandas Series
    if not isinstance(time_series, pd.Series):
        raise TypeError("Expected a pandas Series")
    
    return time_series.apply(parse_time_string).to_frame()

convert_to_minutes_transformer = FunctionTransformer(convert_to_minutes_series)

# %% [markdown]
# ### Convert time column in minutes

# %%
df['time'].apply(lambda x: parse_time_string(x))
# Out:
# 0         140
# 1         788
# 2         123
# 3         676
# 4         600
#          ...
# 87484     454
# 87485     607
# 87486    1144
# 87487     248
# 87488     361
# Name: time, Length: 87489, dtype: int64

# %%
convert_to_minutes_transformer.transform(df['time'])
# Out:
#        time
# 0       140
# 1       788
# 2       123
# 3       676
# 4       600
# ...     ...
# 87484   454
# 87485   607
# 87486  1144
# 87487   248
# 87488   361
#
# [87489 rows x 1 columns]

# %%
from datetime import datetime

def convert_to_ddmmyyyy(date): 
    formatted_date = None
    try:
        # Try parsing with both possible formats
        if '/' in date:
            parsed_date = datetime.strptime(date, "%d/%m/%Y") if len(date.split('/')[-1]) == 4 else datetime.strptime(date, "%d/%m/%y")
        elif '-' in date:
            parsed_date = datetime.strptime(date, "%d-%m-%Y") if len(date.split('-')[-1]) == 4 else datetime.strptime(date, "%d-%m-%y")
        else:
            raise ValueError("Unrecognized date format")
    except ValueError:
        raise TypeError("Expected a pandas Series")
        return None
    else: 
        # Format date to dd/mm/yyyy
        formatted_date = parsed_date.strftime("%d/%m/%Y") 
    return formatted_date

def date_converter(date_series):

    # Ensure the input is a pandas Series
    if not isinstance(date_series, pd.Series):
        raise TypeError("Expected a pandas Series")

    return date_series.apply(convert_to_ddmmyyyy).to_frame()

date_transformer = FunctionTransformer(date_converter)

# %%
 df['releasedate'].apply(lambda x: convert_to_ddmmyyyy(x))
# Out:
# 0        08/04/2008
# 1        05/01/2018
# 2        11/06/2020
# 3        10/05/2021
# 4        13/01/2010
#             ...
# 87484    03/09/2017
# 87485    21/02/2017
# 87486    30/12/2016
# 87487    23/02/2011
# 87488    03/07/2017
# Name: releasedate, Length: 87489, dtype: object

# %%
date_transformer.transform(df['releasedate'])
# Out:
#       releasedate
# 0      08/04/2008
# 1      05/01/2018
# 2      11/06/2020
# 3      10/05/2021
# 4      13/01/2010
# ...           ...
# 87484  03/09/2017
# 87485  21/02/2017
# 87486  30/12/2016
# 87487  23/02/2011
# 87488  03/07/2017
#
# [87489 rows x 1 columns]

# %%
def process_stars_data(stars_string): 
    if "Not rated yet" in stars_string:
        # Handle "Not rated yet"
        stars = ratings = 'Not Rated'
    else:
        # Extract stars (e.g., "4.5" or "5") and ratings (e.g., "34")
        stars_match = re.search(r'(\d+(\.\d+)?) out of 5 stars', stars_string)
        ratings_match = re.search(r'(\d+)\s+ratings', stars_string)

        stars = stars_match.group(1) if stars_match else "Not Rated"
        ratings = ratings_match.group(1) if ratings_match else "Not Rated" 
        
    return stars, ratings


def stars_converter(stars_series):
    # Ensure the input is a pandas Series
    if not isinstance(stars_series, pd.Series):
        raise TypeError("Expected a pandas Series")

    parsed_stars = stars_series.apply(process_stars_data)

    return pd.DataFrame(parsed_stars.tolist(), columns=['rating_stars','ratings'])

stars_transformer = FunctionTransformer(stars_converter)

# %%
df['stars'].apply(process_stars_data)
# Out:
# 0                       (5, 34)
# 1                     (4.5, 41)
# 2                     (4.5, 38)
# 3                     (4.5, 12)
# 4                    (4.5, 181)
#                   ...
# 87484    (Not Rated, Not Rated)
# 87485    (Not Rated, Not Rated)
# 87486    (Not Rated, Not Rated)
# 87487    (Not Rated, Not Rated)
# 87488    (Not Rated, Not Rated)
# Name: stars, Length: 87489, dtype: object

# %%
stars_transformer.transform(df['stars'])
# Out:
#       rating_stars    ratings
# 0                5         34
# 1              4.5         41
# 2              4.5         38
# 3              4.5         12
# 4              4.5        181
# ...            ...        ...
# 87484    Not Rated  Not Rated
# 87485    Not Rated  Not Rated
# 87486    Not Rated  Not Rated
# 87487    Not Rated  Not Rated
# 87488    Not Rated  Not Rated
#
# [87489 rows x 2 columns]

# %% [markdown]
# Apply Columns Trasnformers to clean all columns data

# %%
# Define the ColumnTransformer
column_transformer = ColumnTransformer(
    transformers=[
        ("clean_author", clean_name_transformer, "author"),
        ("clean_narrator", clean_name_transformer, "narrator"),
        ("total_minutes", convert_to_minutes_transformer, "time"),
        ("formatted_date", date_transformer, "releasedate"),
        ("stars_data", stars_transformer, "stars"),
    ],
    remainder="passthrough"  # Keep any other columns untouched
)

# %%
tramsformed_columns = column_transformer.fit_transform(df)
transformed_df=pd.DataFrame(tramsformed_columns, columns=[
        "clean_author", "clean_narrator", "total_minutes", 
        "formatted_date", "stars", "ratings", *df.drop(["author", "narrator", "time", "releasedate", "stars"], axis=1).columns
    ])
transformed_df
# Out:
#            clean_author   clean_narrator total_minutes formatted_date  \
# 0      Geronimo Stilton      Bill Lobely           140     08/04/2008
# 1          Rick Riordan   Robbie Daymond           788     05/01/2018
# 2           Jeff Kinney      Dan Russell           123     11/06/2020
# 3          Rick Riordan  Soneela Nankani           676     10/05/2021
# 4          Rick Riordan  Jesse Bernstein           600     13/01/2010
# ...                 ...              ...           ...            ...
# 87484     Chris Stewart    Chris Stewart           454     03/09/2017
# 87485    Stephen O'Shea      Robert Fass           607     21/02/2017
# 87486        Mark Twain       Flo Gibson          1144     30/12/2016
# 87487   Laurence Sterne     Anton Lesser           248     23/02/2011
# 87488    Mark Kurlansky     Fleet Cooper           361     03/07/2017
#
#            stars    ratings                                        name  \
# 0              5         34                  Geronimo Stilton #11 & #12
# 1            4.5         41                            The Burning Maze
# 2            4.5         38                                The Deep End
# 3            4.5         12                        Daughter of the Deep
# 4            4.5        181  The Lightning Thief: Percy Jackson, Book 1
# ...          ...        ...                                         ...
# 87484  Not Rated  Not Rated                   Last Days of the Bus Club
# 87485  Not Rated  Not Rated                                    The Alps
# 87486  Not Rated  Not Rated                        The Innocents Abroad
# 87487  Not Rated  Not Rated                       A Sentimental Journey
# 87488  Not Rated  Not Rated                                      Havana
#
#       language price
# 0      English   468
# 1      English   820
# 2      English   410
# 3      English   615
# 4      English   820
# ...        ...   ...
# 87484  English   596
# 87485  English   820
# 87486  English   938
# 87487  English   680
# 87488  English   569
#
# [87489 rows x 9 columns]

# %%
transformed_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 87489 entries, 0 to 87488
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   clean_author    87489 non-null  object
#  1   clean_narrator  87489 non-null  object
#  2   total_minutes   87489 non-null  object
#  3   formatted_date  87489 non-null  object
#  4   stars           87489 non-null  object
#  5   ratings         87489 non-null  object
#  6   name            87489 non-null  object
#  7   language        87489 non-null  object
#  8   price           87489 non-null  object
# dtypes: object(9)
# memory usage: 6.0+ MB

# %%
columns = ['name'] + [col for col in transformed_df.columns if col != 'name']

# %%
transformed_df = transformed_df[columns]

# %% [markdown]
# ### Clean Language and Price Columns

# %%
transformed_df['language'] = transformed_df['language'].str.capitalize()
transformed_df['price']= transformed_df['price'].str.replace(',','').replace('Free',0).astype('float')

# %%
transformed_df
# Out:
#                                              name      clean_author  \
# 0                      Geronimo Stilton #11 & #12  Geronimo Stilton
# 1                                The Burning Maze      Rick Riordan
# 2                                    The Deep End       Jeff Kinney
# 3                            Daughter of the Deep      Rick Riordan
# 4      The Lightning Thief: Percy Jackson, Book 1      Rick Riordan
# ...                                           ...               ...
# 87484                   Last Days of the Bus Club     Chris Stewart
# 87485                                    The Alps    Stephen O'Shea
# 87486                        The Innocents Abroad        Mark Twain
# 87487                       A Sentimental Journey   Laurence Sterne
# 87488                                      Havana    Mark Kurlansky
#
#         clean_narrator total_minutes formatted_date      stars    ratings  \
# 0          Bill Lobely           140     08/04/2008          5         34
# 1       Robbie Daymond           788     05/01/2018        4.5         41
# 2          Dan Russell           123     11/06/2020        4.5         38
# 3      Soneela Nankani           676     10/05/2021        4.5         12
# 4      Jesse Bernstein           600     13/01/2010        4.5        181
# ...                ...           ...            ...        ...        ...
# 87484    Chris Stewart           454     03/09/2017  Not Rated  Not Rated
# 87485      Robert Fass           607     21/02/2017  Not Rated  Not Rated
# 87486       Flo Gibson          1144     30/12/2016  Not Rated  Not Rated
# 87487     Anton Lesser           248     23/02/2011  Not Rated  Not Rated
# 87488     Fleet Cooper           361     03/07/2017  Not Rated  Not Rated
#
#       language  price
# 0      English  468.0
# 1      English  820.0
# 2      English  410.0
# 3      English  615.0
# 4      English  820.0
# ...        ...    ...
# 87484  English  596.0
# 87485  English  820.0
# 87486  English  938.0
# 87487  English  680.0
# 87488  English  569.0
#
# [87489 rows x 9 columns]

# %%
# Save the transformed DataFrame to a CSV in a writable directory
transformed_df.to_csv('/kaggle/working/audible_cleaned.csv', index=False)
